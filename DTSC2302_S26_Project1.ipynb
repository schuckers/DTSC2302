# %% [markdown]
# ### DTSC 2302
# ### Ageenko Schuckers
# ### Project 1
# ### Due 3/27/26 7:59pm
#
# For this project you will work in groups but turn in a single report for each of the first three parts below. You’ll turn in this assignment via Gradescope.  You may use generative AI for this project.  For this assignment, you will be building two regression models using a subset of data from the following source:
# [https://archive.ics.uci.edu/dataset/320/student+performance](https://archive.ics.uci.edu/dataset/320/student+performance).
# You will have 600 of the observations for the Portuguese language dataset.  You will build two different models as described below.  The target variable for the analysis is G3, the final year long grade for a Portuguese language course.
#
# You may choose your own groups for this project.  Groups must have between 3 and 5 members and you must send an email to Prof. Schuckers and Prof. Ageenko letting us know about your group’s membership.  If you need to join a group or you want someone to add to your group, please let us know at the appropiate time during class.
#
# The data can be found here:
# [https://webpages.charlotte.edu/mschuck1/classes/DTSC2302/student-performance_n_600.csv](https://webpages.charlotte.edu/mschuck1/classes/DTSC2302/student-performance_n_600.csv)
#
# There are two target audiences for this project.  For Parts 1 and 2, your audience is the data analysis for the local school board who would have interest in your work and is knowledgeable about data analysis/regression.  For Part 3, your audience is the school board and you can expect that members of the school board know little about data analysis and are focused on the well being of student and their academic performance but also on resources and costs.
#
# Your model building process should be clear, robust and involve feature selection, model evaluation, and model assessment.
#
# ### Part I: Using all predictors (40 points)
# For this part you will create a model *considering* all of the possible predictors for G3.
#
#  + Give a one paragraph description of your model building process [10]
#  + Describe the prediction model and interpret two or three of the coefficients.[10]
#  +  Assess overall model quality and model usefulness including out of sample performance [10]
#  + Put the model summary for the final model in an Appendix [5]
#  + Give code for analysis as an appendix [5]
#
# ### Part II: Using all predictors except G1 and G2 ( 40 points)
# For this part you will create a model *considering* all of the predictors for G3 except G1 and G2.
#  + Give a one paragraph description of your model building process [10]
#  + Describe the prediction model and interpret two or three of the coefficients.[10]
#  + Assess overall model quality and model usefulness including out of sample performance [10]
#  + Put the model summary for the final model in an Appendix [5]
#  + Give code for analysis as an appendix [5]
#
# ### Part III: One page summary for school administrators (40 points)
#  + Introduction [10 points]
#  + Summary of results especially drivers of student grades [20 points]
#  + Recommendations for one policy change [10 points] (e.g., "If mother's education is a high predictor, we should launch an adult literacy program to indirectly boost student scores.")
#
# ### Part IV: Groupmate Assessment (60 points)
#  + Actually doing the assessment of your groupmates [10 points]
#  + Average score from your groupmates [50 points]

# %% [markdown]
# ### Notes
# + For each of the first three parts, you should create a separate document to be uploaded to Gradescope.  So you will have three documents to submit.
# + Put all of the names of the members of your group on each document.
# + When you submit to Gradescope, be sure to add all of the group members to your submission.  This can be done after you have submitted.
# + For Parts I and II, you are considering all of the predictors but you don't have to use all of them.
