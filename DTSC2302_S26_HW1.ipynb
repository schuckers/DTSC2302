# %% [markdown]
# ## DTSC 2302 Spring 2026 Homework #1
#
# Turn in your assignment via Gradescope
#
# Due 3/30/26, 7: 59pm

# %% [markdown]
# #### Question 1
# Read in the Penguins dataset (https://webpages.charlotte.edu/mschuck1/classes/DTSC2301/Data/BlueJays.csv).  Fit a logistic regression model to predict Sex of the blue jay using _BillDepth_, _Skull_ and _Head_.  Interpret the coefficients from fitting the model.

# %% [markdown]
# #### Question 2
# Get the predicted log odds that a penguin is male if their BillDepth is 8.11, their Skull size is 30.76 and their Head size is 54.54.
#
# Predict the probability of a penguin being male if their BillDepth is 8.11, their Skull size is 30.76 and their Head size is 54.54.
#
# Predict the probabilty of a penguine being female if their BillDepth is 8.32, their Skull size is 31.07 and their Head size is 58.31.

# %% [markdown]
# #### Question 3
# Find the accuracy, precision, recall and specificity of the model you made in Question 1.

# %% [markdown]
# #### Question 4
# For this question, you will use a new dataset (https://webpages.charlotte.edu/mschuck1/classes/DTSC2301/Data/credit_card_defaults.csv).  Fit a logistic regression with the target variable 'default payment next month' with  *LIMIT_BAL*, *SEX*, and *AGE* as predictors.  Center the *AGE* variable and the *LIMIT_BAL* variable.  Get the confusion matrix for this model.
# Calculate the accuracy of the model, the precision of the model and the recall of the model and explain in words what each of those quantities represents in words.
#
# Be sure to understand your variables before you use them.
#
# Some additional details on this dataset can be found at [<https://archive.ics.uci.edu/dataset/350/default+of+credit+card+clients>].

# %% [markdown]
# #### Question 5
# With the breast cancer dataset, use the features Texture, Radius, Area, Compactness, Symmetry and Smoothness, run 8 fold cross validation for the following models: logistic regression, k-Nearest Neighbors, a decision tree with depth of 3, a decision tree with depth of 5.  Report the average cross validated accuracy for each methodology. Interpret the model that performed the best including suggesting which features were most useful for prediction.
